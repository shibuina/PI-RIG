# %%
import pandas as pd
import matplotlib.pyplot as plt
import io

# Sample data provided by the user.
# The data is structured as a string to be self-contained within the script.
df = pd.read_csv('rlkit/data/08-08-rlkit-pusher-rig-example/08-08-rlkit-pusher-rig-example_2025_08_08_22_33_03_0000--s-37989/vae_progress.csv')


# Plot 'AverageReturn' against 'Number of env steps total'.
# These columns are often used to visualize the learning progress of an agent.
plt.figure(figsize=(10, 6))
plt.plot(df['train/epoch'], df['train/loss'], marker='o')
plt.title('Train Loss vs. Training Epoch VAE')
plt.xlabel('Training Epoch')
plt.ylabel('Train Loss')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import io

# Sample data provided by the user.
# The data is structured as a string to be self-contained within the script.
df = pd.read_csv('rlkit/data/08-08-rlkit-pusher-rig-example/08-08-rlkit-pusher-rig-example_2025_08_08_22_33_03_0000--s-37989/progress.csv')


# Plot 'AverageReturn' against 'Number of env steps total'.
# These columns are often used to visualize the learning progress of an agent.
plt.figure(figsize=(10, 6))
plt.plot(df['Epoch'], df['Policy Loss'], marker='o')
plt.title('Train Loss vs. Training Epoch RIG')
plt.xlabel('Training Epoch')
plt.ylabel('Train Loss')
plt.grid(True)
plt.show()

# %%
df['Total Train Time (s)'].iloc[-1]  # Get the last value of 'Total Train Time (s)' column
# Out:
# np.float64(9486.042323185997)

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Number of env steps total'], df['Final hand_distance Mean'], marker='o')
plt.title('Final hand_distance Mean vs. Number of env steps total RIG')
plt.xlabel('Number of env steps total')
plt.ylabel('Final hand_distance Mean')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Number of env steps total'], df['Final puck_distance Mean'], marker='o')
plt.title('Final puck_distance Mean vs. Number of env steps total RIG')
plt.xlabel('Number of env steps total')
plt.ylabel('Final puck_distance Mean')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Number of env steps total'], df['Final touch_distance Mean'], marker='o')
plt.title('Final touch_distance Mean vs. Number of env steps total RIG')
plt.xlabel('Number of env steps total')
plt.ylabel('Final touch_distance Mean')
plt.grid(True)
plt.show()
